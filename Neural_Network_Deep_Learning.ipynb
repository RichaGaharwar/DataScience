# %% [markdown]
# <a href="https://colab.research.google.com/github/RichaGaharwar/DataScience/blob/main/Neural_Network_Deep_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
